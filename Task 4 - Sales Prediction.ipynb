# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('advertising.csv')
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
plt.scatter(X['TV'],y)
plt.show()

# %%
plt.scatter(X['Radio'],y)
plt.show()

# %%
plt.scatter(X['Newspaper'],y)
plt.show()

# %%
cor = X['TV'].corr(y)
cor
# Out:
# 0.9012079133023306

# %%
cor = X['Radio'].corr(y)
cor
# Out:
# 0.34963109700766914

# %%
cor = X['Newspaper'].corr(y)
cor
# Out:
# 0.15796002615492633

# %%
X = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,y,test_size=1/3,random_state=0)

# %%
X_train
# Out:
# array([[163.5,  36.8,   7.4],
#        [100.4,   9.6,   3.6],
#        [ 76.3,  27.5,  16. ],
#        [184.9,  43.9,   1.7],
#        [134.3,   4.9,   9.3],
#        [273.7,  28.9,  59.7],
#        [296.4,  36.3, 100.9],
#        [ 96.2,  14.8,  38.9],
#        [109.8,  47.8,  51.4],
#        [255.4,  26.9,   5.5],
#        [204.1,  32.9,  46. ],
#        [240.1,  16.7,  22.9],
#        [193.7,  35.4,  75.6],
#        [191.1,  28.7,  18.2],
#        [ 89.7,   9.9,  35.7],
#        [ 43. ,  25.9,  20.5],
#        [ 38.2,   3.7,  13.8],
#        [ 13.1,   0.4,  25.6],
#        [239.3,  15.5,  27.3],
#        [ 17.2,  45.9,  69.3],
#        [210.7,  29.5,   9.3],
#        [ 25.6,  39. ,   9.3],
#        [177. ,   9.3,   6.4],
#        [206.9,   8.4,  26.4],
#        [ 66.1,   5.8,  24.2],
#        [149.7,  35.6,   6. ],
#        [129.4,   5.7,  31.3],
#        [ 94.2,   4.9,   8.1],
#        [276.7,   2.3,  23.7],
#        [276.9,  48.9,  41.8],
#        [  7.8,  38.9,  50.6],
#        [250.9,  36.5,  72.3],
#        [175.7,  15.4,   2.4],
#        [ 11.7,  36.9,  45.2],
#        [ 75.5,  10.8,   6. ],
#        [199.8,   3.1,  34.6],
#        [230.1,  37.8,  69.2],
#        [107.4,  14. ,  10.9],
#        [225.8,   8.2,  56.5],
#        [163.3,  31.6,  52.9],
#        [131.1,  42.8,  28.9],
#        [206.8,   5.2,  19.4],
#        [177. ,  33.4,  38.7],
#        [216.8,  43.9,  27.2],
#        [ 66.9,  11.7,  36.8],
#        [227.2,  15.8,  49.9],
#        [193.2,  18.4,  65.7],
#        [ 97.5,   7.6,   7.2],
#        [ 85.7,  35.8,  49.3],
#        [228.3,  16.9,  26.2],
#        [139.5,   2.1,  26.6],
#        [ 48.3,  47. ,   8.5],
#        [218.4,  27.7,  53.4],
#        [195.4,  47.7,  52.9],
#        [  5.4,  29.9,   9.4],
#        [238.2,  34.3,   5.3],
#        [216.4,  41.7,  39.6],
#        [222.4,   4.3,  49.8],
#        [ 27.5,   1.6,  20.7],
#        [151.5,  41.3,  58.5],
#        [139.2,  14.3,  25.6],
#        [117.2,  14.7,   5.4],
#        [283.6,  42. ,  66.2],
#        [ 57.5,  32.8,  23.5],
#        [237.4,  27.5,  11. ],
#        [213.5,  43. ,  33.8],
#        [ 18.8,  21.7,  50.4],
#        [  4.1,  11.6,   5.7],
#        [164.5,  20.9,  47.4],
#        [ 93.9,  43.5,  50.5],
#        [ 28.6,   1.5,  33. ],
#        [232.1,   8.6,   8.7],
#        [214.7,  24. ,   4. ],
#        [ 19.4,  16. ,  22.3],
#        [280.2,  10.1,  21.4],
#        [290.7,   4.1,   8.5],
#        [136.2,  19.2,  16.6],
#        [ 69. ,   9.3,   0.9],
#        [ 44.5,  39.3,  45.1],
#        [141.3,  26.8,  46.2],
#        [188.4,  18.1,  25.6],
#        [293.6,  27.7,   1.8],
#        [137.9,  46.4,  59. ],
#        [  8.4,  27.2,   2.1],
#        [168.4,   7.1,  12.8],
#        [281.4,  39.6,  55.8],
#        [ 43.1,  26.7,  35.1],
#        [219.8,  33.5,  45.1],
#        [182.6,  46.2,  58.7],
#        [149.8,   1.3,  24.3],
#        [220.3,  49. ,   3.2],
#        [ 95.7,   1.4,   7.4],
#        [248.8,  27.1,  22.9],
#        [ 78.2,  46.8,  34.5],
#        [121. ,   8.4,  48.7],
#        [112.9,  17.4,  38.6],
#        [ 17.9,  37.6,  21.6],
#        [ 80.2,   0. ,   9.2],
#        [248.4,  30.2,  20.3],
#        [ 97.2,   1.5,  30. ],
#        [220.5,  33.2,  37.9],
#        [284.3,  10.6,   6.4],
#        [243.2,  49. ,  44.3],
#        [ 70.6,  16. ,  40.8],
#        [135.2,  41.7,  45.9],
#        [ 75.3,  20.3,  32.5],
#        [116. ,   7.7,  23.1],
#        [ 75.1,  35. ,  52.7],
#        [ 38. ,  40.3,  11.9],
#        [166.8,  42. ,   3.6],
#        [ 26.8,  33. ,  19.3],
#        [120.5,  28.5,  14.2],
#        [262.9,   3.5,  19.5],
#        [234.5,   3.4,  84.8],
#        [239.8,   4.1,  36.9],
#        [286. ,  13.9,   3.7],
#        [222.4,   3.4,  13.1],
#        [ 39.5,  41.1,   5.8],
#        [228. ,  37.7,  32. ],
#        [210.8,  49.6,  37.7],
#        [ 73.4,  17. ,  12.9],
#        [ 88.3,  25.5,  73.4],
#        [199.1,  30.6,  38.7],
#        [110.7,  40.6,  63.2],
#        [266.9,  43.8,   5. ],
#        [237.4,   5.1,  23.5],
#        [199.8,   2.6,  21.2],
#        [187.9,  17.2,  17.9],
#        [139.3,  14.5,  10.2],
#        [ 17.2,   4.1,  31.6],
#        [ 76.4,   0.8,  14.8],
#        [239.9,  41.5,  18.5],
#        [ 19.6,  20.1,  17. ]])

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([10.69080376,  8.65780293,  9.59084227, 25.13506009, 14.77497167,
#         8.36256185, 10.74283145, 18.4293824 ,  9.99242351, 17.93510426,
#        23.65344994, 10.7108131 , 13.38842006, 17.1470691 , 11.78374995,
#        13.33004823, 21.20638053,  9.09833147, 14.29095047, 18.93183374,
#        25.15325265, 12.43071475, 16.67409103, 13.87727542,  7.78130577,
#        15.16626254, 14.72662177, 20.78694256, 17.0289183 ,  8.95292575,
#        12.66378496, 21.04281827, 21.43585072, 21.98648976,  7.23003896,
#         7.03448123,  9.28563689, 15.74371883, 13.37620489,  7.26842591,
#        11.09126734,  9.06928822, 15.64458646, 18.27286879, 19.04360249,
#        13.49385818,  5.31207734, 10.64203863, 15.73734907, 10.99146031,
#        12.22727021, 20.82184305, 20.79085698, 17.01153452,  9.96486522,
#         9.43435563, 23.7217786 , 16.03942513, 18.13334267,  8.25403092,
#        19.38336647, 15.69946284, 17.09765359, 15.29548717, 18.40809881,
#        20.27863526, 22.07411871])

# %%
from sklearn.metrics import r2_score

# %%
r2_score = r2_score(Y_test,y_pred)
r2_score
# Out:
# 0.8671668543617773

# %%
regressor.predict([[44,40,45]])
# Out:
# array([11.57822475])
